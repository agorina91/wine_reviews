# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/Users/anastasiagorina/Desktop/Projects/wine_reviews/Data/winemag-data-130k-v2.csv')
df.drop(columns="Unnamed: 0", inplace=True)

# %%
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
by_country = df.groupby('country')['title'].count()
plt.figure(figsize = (16,10))
by_country.plot.bar()

# %%
by_province = df.groupby('province')['title'].count()
plt.figure(figsize = (16,10))
by_province.plot.bar()

# %%
##points
by_points = df.groupby('points')['title'].count()
plt.figure(figsize = (16,10))
by_points.plot.bar()

# %%
##variety

by_variety = df.groupby('variety')['title'].count()
plt.figure(figsize = (16,10))
by_variety.plot.bar()

# %%
df.variety.value_counts()
# Out:
# Pinot Noir                  13272
# Chardonnay                  11753
# Cabernet Sauvignon           9472
# Red Blend                    8946
# Bordeaux-style Red Blend     6915
#                             ...
# Franconia                       1
# Vranac                          1
# Syrah-Bonarda                   1
# Loureiro-Arinto                 1
# Barbera-Nebbiolo                1
# Name: variety, Length: 707, dtype: int64

# %%
df.shape
# Out:
# (129971, 13)

# %%
df.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
#price
by_price = df.groupby('price')['title'].count()
plt.figure(figsize = (16,10))
by_price.plot.bar()

# %%
df.price.value_counts()
# Out:
# 20.0      6940
# 15.0      6066
# 25.0      5805
# 30.0      4951
# 18.0      4883
#           ...
# 216.0        1
# 247.0        1
# 1900.0       1
# 602.0        1
# 820.0        1
# Name: price, Length: 390, dtype: int64

# %%
df.taster_name.value_counts()
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
df.description.isna().sum()
# Out:
# 0

# %%
text = " ".join(word for word in df.description)

# %%
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
# the matplotlib way:
plt.figure(figsize = (16,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
df.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# std         3.039730      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %%
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
df.winery.value_counts()
# Out:
# Wines & Winemakers        222
# Testarossa                218
# DFJ Vinhos                215
# Williams Selyem           211
# Louis Latour              199
#                          ...
# Familly Valéry              1
# Ancient Roots               1
# Gilga                       1
# Domaine de la Jobeline      1
# Château Moulin Lafitte      1
# Name: winery, Length: 16757, dtype: int64

# %%
df.variety.value_counts()
# Out:
# Pinot Noir                  13272
# Chardonnay                  11753
# Cabernet Sauvignon           9472
# Red Blend                    8946
# Bordeaux-style Red Blend     6915
#                             ...
# Otskhanuri Sapere               1
# Gamza                           1
# Barbera-Nebbiolo                1
# Paralleda                       1
# Prunelard                       1
# Name: variety, Length: 707, dtype: int64

# %%
df.shape
# Out:
# (129971, 13)

# %%
import markovify
import string
import re

# %%
def strip_punct(string):
    no_punct_string = re.sub(r'[^\w\s]','', string)
    return no_punct_string

# %%
strip_punct(df.description[1])
# Out:
# 'This is ripe and fruity a wine that is smooth while still structured Firm tannins are filled out with juicy red berry fruits and freshened with acidity Its  already drinkable although it will certainly be better from 2016'

# %%
df['description'] = df.apply(lambda row: strip_punct(row['description']), axis=1)

# %%
text_model = markovify.NewlineText(df.description, state_size = 2)

# %%
for i in range(5):
    print(text_model.make_sentence())
# Out:
# With overtly sweet with citrus zest Its simple but refreshing rounded white with touches of butter baking spice and blackberry preserves and muddled with flavors of coconutvanilla cream Its medium in body its almost undrinkable now in Ribera del Duero This is off dry this is a simple onedimensional wine
# Solid black cherry and tart finishing on a jammy deepfruited finish give the wine shows the bright clean character that comes from the playfulness of this accessible wine
# ...

# %%
from __future__ import print_function
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
raw = df.description

# %%
tf_vectorizer = CountVectorizer(strip_accents = 'unicode',
                                stop_words = 'english',
                                lowercase = True,
                                token_pattern = r'\b[a-zA-Z]{3,}\b',
                                max_df = 0.5, 
                                min_df = 10)
dtm_tf = tf_vectorizer.fit_transform(raw)

# %%
tfidf_vectorizer = TfidfVectorizer(**tf_vectorizer.get_params())
dtm_tfidf = tfidf_vectorizer.fit_transform(raw)
# Out:
# /Users/anastasiagorina/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:1817: UserWarning: Only (<class 'numpy.float64'>, <class 'numpy.float32'>, <class 'numpy.float16'>) 'dtype' should be used. <class 'numpy.int64'> 'dtype' will be converted to np.float64.
#   UserWarning)

# %%
lda_tf = LatentDirichletAllocation(n_components=2, random_state=0)
lda_tf.fit(dtm_tf)
# for TFIDF DTM
lda_tfidf = LatentDirichletAllocation(n_components=2, random_state=0)
lda_tfidf.fit(dtm_tfidf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=2, n_jobs=None,
#                           perp_tol=0.1, random_state=0, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
pyLDAvis.sklearn.prepare(lda_tf, dtm_tf, tf_vectorizer)
# Out:
# PreparedData(topic_coordinates=              x    y  topics  cluster       Freq
# topic
# 0      0.116811  0.0       1        1  54.345838
# 1     -0.116811  0.0       2        1  45.654162, topic_info=         Term          Freq         Total Category  logprob  loglift
# 1261   cherry  29215.000000  29215.000000  Default  30.0000  30.0000
# 648     black  28919.000000  28919.000000  Default  29.0000  29.0000
# 59    acidity  34933.000000  34933.000000  Default  28.0000  28.0000
# 289     apple  13559.000000  13559.000000  Default  27.0000  27.0000
# 8279     wine  80171.000000  80171.000000  Default  26.0000  26.0000
# ...       ...           ...           ...      ...      ...      ...
# 337    aromas  11842.596882  39518.412433   Topic2  -4.7641  -0.4210
# 7340    sweet   6948.416949  13409.519175   Topic2  -5.2973   0.1266
# 4901    notes   7500.579181  18993.129557   Topic2  -5.2208  -0.1450
# 4895     nose   7221.781291  16916.197167   Topic2  -5.2587  -0.0671
# ...
